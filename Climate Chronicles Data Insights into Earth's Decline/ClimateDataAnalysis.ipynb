# %%
import pandas as pd

# Assuming the dataset is in a CSV file
dataset_path = 'dataset/GlobalTemperatures.csv'

# Read the dataset into a pandas DataFrame
df = pd.read_csv(dataset_path)
df.groupby()
#create a fuctin to get the average temperature of a given year
df.groupby
import

# %%
# Out:
#               dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0     1750-01-01                   3.034                              3.574
# 1     1750-02-01                   3.083                              3.702
# 2     1750-03-01                   5.626                              3.076
# 3     1750-04-01                   8.490                              2.451
# 4     1750-05-01                  11.573                              2.072
# ...          ...                     ...                                ...
# 3187  2015-08-01                  14.755                              0.072
# 3188  2015-09-01                  12.999                              0.079
# 3189  2015-10-01                  10.801                              0.102
# 3190  2015-11-01                   7.433                              0.119
# 3191  2015-12-01                   5.518                              0.100
#
# ...

# %%
dataset_path2 = 'dataset/GlobalLandTemperaturesByCity.csv'
dataset_path3 = 'dataset/GlobalLandTemperaturesByCountry.csv'
dataset_path4 = 'dataset/GlobalLandTemperaturesByMajorCity.csv'
dataset_path5 = 'dataset/GlobalLandTemperaturesByState.csv'

# Read the datasets into pandas DataFrames
df2 = pd.read_csv(dataset_path2)
df3 = pd.read_csv(dataset_path3)
df4 = pd.read_csv(dataset_path4)
df5 = pd.read_csv(dataset_path5)

# %%
#explain the meaning behind each column in the dataframe df
df.info()
df.describe()
df.head()
# Out:
#               dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0     1750-01-01                   3.034                              3.574
# 1     1750-02-01                   3.083                              3.702
# 2     1750-03-01                   5.626                              3.076
# 3     1750-04-01                   8.490                              2.451
# 4     1750-05-01                  11.573                              2.072
# ...          ...                     ...                                ...
# 3187  2015-08-01                  14.755                              0.072
# 3188  2015-09-01                  12.999                              0.079
# 3189  2015-10-01                  10.801                              0.102
# 3190  2015-11-01                   7.433                              0.119
# 3191  2015-12-01                   5.518                              0.100
#
# ...

# %%
df.head()
# Out:
#            dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0  1750-01-01                   3.034                              3.574
# 1  1750-02-01                   3.083                              3.702
# 2  1750-03-01                   5.626                              3.076
# 3  1750-04-01                   8.490                              2.451
# 4  1750-05-01                  11.573                              2.072
#
#    LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 0                 NaN                            NaN                 NaN
# 1                 NaN                            NaN                 NaN
# 2                 NaN                            NaN                 NaN
# 3                 NaN                            NaN                 NaN
# 4                 NaN                            NaN                 NaN
#
#    LandMinTemperatureUncertainty  LandAndOceanAverageTemperature  \
# ...

# %%
#preview all the dataframes and their columns and see if there are any columns that can be used to join the dataframes
df 
df2
df3
df4
df5
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0       1855-05-01              25.544                          1.171
# 1       1855-06-01              24.228                          1.103
# 2       1855-07-01              24.371                          1.044
# 3       1855-08-01              25.427                          1.073
# 4       1855-09-01              25.675                          1.014
# ...            ...                 ...                            ...
# 645670  2013-05-01              21.634                          0.578
# 645671  2013-06-01              24.679                          0.596
# 645672  2013-07-01              29.272                          1.340
# 645673  2013-08-01              29.202                          0.869
# 645674  2013-09-01                 NaN                            NaN
#
#            State Country
# 0           Acre  Brazil
# 1           Acre  Brazil
# 2           Acre  Brazil
# ...

# %%
#do a join on the dataframes to see if there are any columns that can be used to join the dataframes
df.merge(df2, on='dt', how='left')
#this join shows that the dt column can be used to join df and df2
#left join is used because we want to keep all the rows in df and only add the columns from df2 that match the dt column in df
# Out:
#                  dt  LandAverageTemperature  \
# 0        1750-01-01                   3.034
# 1        1750-01-01                   3.034
# 2        1750-01-01                   3.034
# 3        1750-01-01                   3.034
# 4        1750-01-01                   3.034
# ...             ...                     ...
# 8546990  2015-08-01                  14.755
# 8546991  2015-09-01                  12.999
# 8546992  2015-10-01                  10.801
# 8546993  2015-11-01                   7.433
# 8546994  2015-12-01                   5.518
#
#          LandAverageTemperatureUncertainty  LandMaxTemperature  \
# 0                                    3.574                 NaN
# 1                                    3.574                 NaN
# 2                                    3.574                 NaN
# 3                                    3.574                 NaN
# 4                                    3.574                 NaN
# ...

# %%
df.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 f
#
# NameError: name 'f' is not defined
